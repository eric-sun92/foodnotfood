# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
import ast

# %%
with open("imagenet1000_clsidx_to_labels.txt", "r") as f:
    imagenet_classes_dict = ast.literal_eval(f.read())

# %%
imagenet_classes_dict
# Out:
# {0: 'tench, Tinca tinca',
#  1: 'goldfish, Carassius auratus',
#  2: 'great white shark, white shark, man-eater, man-eating shark, Carcharodon carcharias',
#  3: 'tiger shark, Galeocerdo cuvieri',
#  4: 'hammerhead, hammerhead shark',
#  5: 'electric ray, crampfish, numbfish, torpedo',
#  6: 'stingray',
#  7: 'cock',
#  8: 'hen',
#  9: 'ostrich, Struthio camelus',
#  10: 'brambling, Fringilla montifringilla',
#  11: 'goldfinch, Carduelis carduelis',
#  12: 'house finch, linnet, Carpodacus mexicanus',
#  13: 'junco, snowbird',
#  14: 'indigo bunting, indigo finch, indigo bird, Passerina cyanea',
#  15: 'robin, American robin, Turdus migratorius',
#  16: 'bulbul',
#  17: 'jay',
#  18: 'magpie',
#  19: 'chickadee',
#  20: 'water ouzel, dipper',
#  21: 'kite',
#  22: 'bald eagle, American eagle, Haliaeetus leucocephalus',
#  23: 'vulture',
#  24: 'great grey owl, great gray owl, Strix nebulosa',
#  25: 'European fire salamander, Salamandra salamandra',
# ...

# %%
for key, value in imagenet_classes_dict.items():
    if "banana" in value:
        print(key)
# Out:
# 954

# %%
import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package wordnet to /Users/ericsun/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.corpus import wordnet as wn

food = wn.synset('food.n.02')
food_list = list(set([w for s in food.closure(lambda s:s.hyponyms()) for w in s.lemma_names()]))
# Out:
# /Users/ericsun/Desktop/foodnotfood/env/lib/python3.11/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('lunch_meat.n.01') at depth 3
#   for synset in acyclic_breadth_first(self, rel, depth):
# /Users/ericsun/Desktop/foodnotfood/env/lib/python3.11/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('headcheese.n.01') at depth 3
#   for synset in acyclic_breadth_first(self, rel, depth):
# /Users/ericsun/Desktop/foodnotfood/env/lib/python3.11/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('haslet.n.01') at depth 3
#   for synset in acyclic_breadth_first(self, rel, depth):
# /Users/ericsun/Desktop/foodnotfood/env/lib/python3.11/site-packages/nltk/corpus/reader/wordnet.py:604: UserWarning: Discarded redundant search for Synset('leg_of_lamb.n.01') at depth 5
#   for synset in acyclic_breadth_first(self, rel, depth):
# ...

# %%
len(food_list)
# Out:
# 1621

# %%
food_list[:5]
# Out:
# ['Emmentaler', 'rump_steak', 'mahimahi', 'spice_cookie', 'chou']

# %%
"banana" in food_list
# Out:
# True

# %%
# filter foods out of food list

for food_item in food_list:
    print(food_item.lower().strip("_"))
# Out:
# emmentaler
# rump_steak
# mahimahi
# spice_cookie
# chou
# wax_bean
# swedish_rye
# anchovy
# spanish_mackerel
# rhubarb_pie
# beach_plum
# cupcake
# leaf_mustard
# hot_cross_bun
# date
# garden_cress
# valencia_orange
# butterbean
# picnic_shoulder
# tamarind
# cornmeal_mush
# triple_creme
# vienna_roll
# turkey
# delmonico_steak
# collards
# jamaica_apple
# beef_neck
# side
# shoofly_pie
# boston_cream_pie
# ackee
# red_currant
# mustard_greens
# toad-in-the-hole
# pepperoni
# celery_root
# grey_mullet
# wild_spinach
# tournedos
# edible_fruit
# snap
# lobster_tart
# seville_orange
# chiffon_cake
# health_food
# sapodilla_plum
# cruciferous_vegetable
# dumpling
# soft-shelled_crab
# salad_greens
# home-fried_potatoes
# muscat
# bell_pepper
# steak_and_kidney_pie
# cake_mix
# napoleon
# marrow
# green_bean
# winter_squash
# jewish_rye
# ship_biscuit
# brisling
# cayenne_pepper
# dandelion_green
# calves'_liver
# common_sorrel
# side_of_pork
# smoked_eel
# huitre
# chili
# boeuf
# ...
